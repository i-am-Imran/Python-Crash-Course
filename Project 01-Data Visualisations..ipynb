# %%
Go to https://matplotlib.org/gallery/
-for sample visualitions you can make using matplotlib with codes.

install matplotlib.
python -m pip install --user matplotlib
$ python3 -m pip install --user matplotlib

# %%
import matplotlib.pyplot as plt

squares = [x**2 for x in range(6)]

fig, ax = plt.subplots()
ax.plot(squares)

plt.show()

# %%
#Increase readibility

# %%
import matplotlib.pyplot as plt
data = [x**2 for x in range(1,6)]

fig,ax = plt.subplots()

ax.plot(data, linewidth = 2.5)

#Set labels
ax.set_title("Values vs Value's square plotiing.",fontsize = 18)
ax.set_xlabel("Value", fontsize = 18)
ax.set_ylabel("Square of Value", fontsize = 18)

#Resizing label.
ax.tick_params(axis='both', labelsize = 14)

plt.show()

# %%
#Square of 4 is 25?? Let's fix that as our graph should start from 1.
#But here it starts from Zero.

# %%
import matplotlib.pyplot as plt

#inbuilt themes for plotting
styles = plt.style.available

# %%
styles
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
import matplotlib.pyplot as plt

plt.style.use('seaborn-deep')
fig, ax = plt.subplots()
ax.scatter(2, 4, s=200)

# Set chart title and label axes.
ax.set_title('Square Numbers',fontsize = 20)
ax.set_xlabel('Value', fontsize=14)
ax.set_ylabel('Square of Value', fontsize=14)

# Set size of tick labels
ax.tick_params(axis='both', which='major', labelsize=14)

# %%
x_values = range(1, 1001)
y_values = [x**2 for x in x_values]

plt.style.use('seaborn-dark')
fig, ax = plt.subplots()
ax.scatter(x_values,y_values,c=y_values,cmap=plt.cm.Blues,s=10)
ax.axis([0, 1100, 0, 1100000])
plt.savefig('hello.png')

# %%
x_val = [x for x in range(1,6)]
y_val = [x**3 for x in x_val]

plt.style.use('seaborn')
fig, ax = plt.subplots()

ax.scatter(x_val,y_val,cmap=plt.cm.Blues,s=100)
ax.set_title('Cubes',fontsize=20)
ax.set_ylabel('Cube',fontsize=20)
ax.set_xlabel('Series of num',fontsize=20)
plt.show()

# %%
x_val = [x for x in range(1,5001)]
y_val = [x**3 for x in x_val]

plt.style.use('seaborn')

fig,ax = plt.subplots()
ax.scatter(x_val,y_val,c='g', s=10)
ax.set_title("KING", fontsize=20)
ax.set_xlabel("Numbers",fontsize=20)
ax.set_ylabel("Cubes",fontsize=20)
ax.tick_params(axis='both',labelsize=15)
plt.savefig('Green_Cubes.png')

# %%
import matplotlib.pyplot as plt

# %%
x = [x for x in range(1,51)]
y = [y**2 for y in range(1,51)]

# %%
fig,ax = plt.subplots()
plt.style.use('seaborn')
ax.scatter(x,y,cmap=plt.cm.Blues,s=10)
ax.set_title('Hello_random',fontsize=20)
ax.tick_params(axis='both',labelsize=15)

# %%
from random import choice

class RandomWalk:
    """A class to generate random walks"""
    
    def __init__(self,num_points=5000):
        """Initialize attributes of a walk"""
        self.num_points = num_points
        
        #All walks start at 0
        self.x_values = [0]
        self.y_values = [0]
    
    def fill_walk(self):
        '''calculate all points in the walk'''
        
        #keep taking steps until walk 
        # reaches the desired length
        
        while len(self.x_values) < self.num_points:
            
            '''
            Decide which direction to go and how
            far to go in that direction.
            '''
            x_direction = choice([1, -1])
            x_distance = choice([0, 1, 2, 3, 4])
            x_step = x_direction * x_distance
            
            y_direction = choice([1,-1])\
            y_distance = choice([0,1, 2, 3, 4])
            y_step = y_direction * y_distance
            
            
            #Reject moves that goes nowhere
            if x_step == 0 and y_step == 0:
                continue
                
             #Calculate the new position
            
            x = self.x_values[-1] + x_step
            y = self.y_values[-1] + y_step
            
            self.x_values.append(x)
            self.y_values.append(y)

# %%
from random import choice

class RandomWalk:
    
    def __init__(self,num_points=5000):
        self.num_points = num_points
        
        self.x_values = [0]
        self.y_values = [0]
        
    def fill_walk(self):
        if len(self.x_values) < self.num_points:
            
            #claculate which direction to go and how
            #far to go in that direction
            x_direction = choice([1,-1])
            x_distance = choice([1,2,3,4])
            x_points = x_direction * x_distance
            
            y_distance = ([1, -1])
            y_direction = ([0, 1, 2, 3, 4])
            y_step = y_direction * y_distance
            
            if x_step == 0 and y_step == 0:
                continue
                
            
            #calculate the new position
            
            x = self.x_values[-1] + x_step
            y = self.y_values[-1] + y_step
            
            self.x_values.append(x)
            self.y_values.append(y)
# Out:
#   File "<ipython-input-36-f95164d2254d>", line 25
#     continue
#     ^
# SyntaxError: 'continue' not properly in loop
